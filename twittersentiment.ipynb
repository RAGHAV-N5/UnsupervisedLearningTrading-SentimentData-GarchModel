# %%
#This is the project to invest, minimize risk of our portfolio by using the twitter data of people's reaction towards stocks

# %%
#import necessary libraries

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt 
import os
import datetime as dt 
plt.style.use('ggplot')
sentiment_df = pd.read_csv('sentiment_data.csv')
sentiment_df.head()
# Out:
#          date symbol  twitterPosts  twitterComments  twitterLikes  \
# 0  2021-11-18   AAPL         811.0           2592.0       21674.0
# 1  2021-11-18    ABT          21.0              3.0          13.0
# 2  2021-11-18    AMD         150.0            675.0        2949.0
# 3  2021-11-18   AMZN         557.0           1315.0       12969.0
# 4  2021-11-18   ATVI          82.0             36.0         131.0
#
#    twitterImpressions  twitterSentiment
# 0           7981808.0               NaN
# 1             64089.0               NaN
# 2           1645270.0               NaN
# 3           5590695.0               NaN
# 4           1310715.0               NaN

# %%
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

# %%
sentiment_df = sentiment_df.set_index(['date','symbol'])
sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN
#            ABT                64089.0               NaN
# ...

# %%
#The returns are not so good if we don't consider engagement_ratio instead of twitterComments or twitterLikes

# %%
sentiment_df['engagement_ratio'] = sentiment_df['twitterComments']/sentiment_df['twitterLikes']
sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            ABT             21.0              3.0          13.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
# ...                         ...              ...           ...
# 2023-01-04 TMO             21.0              2.0          32.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %%
#filter out the best stocks based on engagement

# %%
sentiment_df = sentiment_df[(sentiment_df['twitterLikes']>20) & (sentiment_df['twitterComments']>10)] 
sentiment_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagement_ratio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN          0.119590
# ...

# %%
aggregated_df = (sentiment_df.reset_index('symbol').groupby([pd.Grouper(freq='M'),'symbol'])[['engagement_ratio']].mean()) 
aggregated_df['rank'] = (aggregated_df.groupby(level=0)['engagement_ratio'].transform(lambda x: x.rank(ascending=False)))
aggregated_df
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-11-30 AAL             0.203835  37.0
#            AAPL            0.256318  23.0
#            ABBV            0.244677  26.0
#            ABT             0.313368  14.0
#            AES             0.864613   2.0
# ...                             ...   ...
# 2023-01-31 TMO             0.333313  19.0
#            TSLA            0.151992  72.0
#            TSN             0.280553  30.0
#            V               0.194045  60.0
#            XOM             0.217904  53.0
#
# [1109 rows x 2 columns]

# %%
filtered_df = aggregated_df[aggregated_df['rank']<6]
filtered_df = filtered_df.reset_index(level=1)
filtered_df.index = filtered_df.index+pd.DateOffset(1) 
filtered_df
# Out:
#            symbol  engagement_ratio  rank
# date
# 2021-12-01    AES          0.864613   2.0
# 2021-12-01    FCX          0.626323   5.0
# 2021-12-01   MNST          0.699721   3.0
# 2021-12-01    OXY          2.147741   1.0
# 2021-12-01    SLB          0.647374   4.0
# ...           ...               ...   ...
# 2023-02-01      A          0.471572   5.0
# 2023-02-01    AES          0.533809   4.0
# 2023-02-01   BIIB          0.839303   1.0
# 2023-02-01    FCX          0.667387   3.0
# 2023-02-01    MDT          0.806841   2.0
#
# [75 rows x 3 columns]

# %%
filtered_df = filtered_df.reset_index().set_index(['date','symbol'])
filtered_df
# Out:
#                    engagement_ratio  rank
# date       symbol
# 2021-12-01 AES             0.864613   2.0
#            FCX             0.626323   5.0
#            MNST            0.699721   3.0
#            OXY             2.147741   1.0
#            SLB             0.647374   4.0
# ...                             ...   ...
# 2023-02-01 A               0.471572   5.0
#            AES             0.533809   4.0
#            BIIB            0.839303   1.0
#            FCX             0.667387   3.0
#            MDT             0.806841   2.0
#
# [75 rows x 2 columns]

# %%
#extract the stocks to form portfolios with at the start of each new month

# %%
dates = filtered_df.index.get_level_values('date').unique().tolist()
fixed_dates = {}
for d in dates: 
    fixed_dates[d.strftime('%Y-%m-%d')] = filtered_df.xs(d, level=0).index.tolist()
fixed_dates
# Out:
# {'2021-12-01': ['AES', 'FCX', 'MNST', 'OXY', 'SLB'],
#  '2022-01-01': ['D', 'FCX', 'L', 'LUV', 'MA'],
#  '2022-02-01': ['AMD', 'D', 'FCX', 'LUV', 'MA'],
#  '2022-03-01': ['FCX', 'GILD', 'LUV', 'MRO', 'OXY'],
#  '2022-04-01': ['A', 'CRM', 'PFE', 'PM', 'STZ'],
#  '2022-05-01': ['AMD', 'CRM', 'CVX', 'J', 'KEY'],
#  '2022-06-01': ['AMD', 'DD', 'FCX', 'KEY', 'LMT'],
#  '2022-07-01': ['CB', 'CRM', 'DD', 'FCX', 'STZ'],
#  '2022-08-01': ['A', 'DD', 'JPM', 'REGN', 'STZ'],
#  '2022-09-01': ['ABT', 'DIS', 'L', 'META', 'MRNA'],
#  '2022-10-01': ['J', 'KEY', 'L', 'META', 'MU'],
#  '2022-11-01': ['A', 'DD', 'FCX', 'J', 'META'],
#  '2022-12-01': ['AEP', 'AES', 'DD', 'J', 'STZ'],
#  '2023-01-01': ['A', 'AES', 'DAL', 'J', 'KEY'],
#  '2023-02-01': ['A', 'AES', 'BIIB', 'FCX', 'MDT']}

# %%
#download fresh stock prices for only selected/shortlisted stocks

# %%
stocks_list = sentiment_df.index.get_level_values('symbol').unique().tolist()
prices_df = yf.download(tickers=stocks_list,
                        start='2021-01-01',
                        end = '2023-03-01')
# Out:
# [*********************100%%**********************]  85 of 85 completed

# %%
#calculate portfolio returns with monthly rebalancing

# %%
returns_df = np.log(prices_df['Adj Close']).diff()

# %%
returns_df = returns_df.dropna()
returns_df
# Out:
#                    A       AAL       AAP      AAPL      ABBV       ABT  \
# Date
# 2021-01-05  0.008143  0.019634 -0.001081  0.012288  0.010288  0.012297
# 2021-01-06  0.027053  0.005816  0.056165 -0.034241 -0.008676 -0.002084
# 2021-01-07  0.026261 -0.009062  0.008505  0.033554  0.010646  0.009660
# 2021-01-08  0.007108 -0.016388  0.014154  0.008594  0.005234  0.002781
# 2021-01-11  0.008542 -0.008629  0.005629 -0.023523  0.016182 -0.006923
# ...              ...       ...       ...       ...       ...       ...
# 2023-02-22 -0.009387 -0.008320 -0.003961  0.002892 -0.008789 -0.009305
# 2023-02-23  0.007852  0.019727 -0.011274  0.003285  0.009249 -0.001364
# 2023-02-24 -0.014065 -0.019727 -0.022503 -0.018169  0.004200 -0.020591
# 2023-02-27  0.006917  0.004489  0.012738  0.008214  0.010228 -0.006892
# 2023-02-28 -0.001478  0.022146  0.030325 -0.003454 -0.002466  0.019356
#
#                  AEP       AES       ALB       AMD  ...       RCL      REGN  \
# ...

# %%
portfolio_df = pd.DataFrame()
for start_date in fixed_dates.keys():
    end_date = (pd.to_datetime(start_date)+pd.offsets.MonthEnd()).strftime('%Y-%m-%d')
    print(start_date)
    print(end_date)
    cols = fixed_dates[start_date]
    print(cols)
    temp_df = returns_df[start_date:end_date][cols].mean(axis=1).to_frame('portfolio_return')
    portfolio_df = pd.concat([portfolio_df, temp_df], axis=0)
# Out:
# 2021-12-01
# 2021-12-31
# ['AES', 'FCX', 'MNST', 'OXY', 'SLB']
# 2022-01-01
# 2022-01-31
# ['D', 'FCX', 'L', 'LUV', 'MA']
# 2022-02-01
# 2022-02-28
# ['AMD', 'D', 'FCX', 'LUV', 'MA']
# 2022-03-01
# 2022-03-31
# ['FCX', 'GILD', 'LUV', 'MRO', 'OXY']
# 2022-04-01
# 2022-04-30
# ['A', 'CRM', 'PFE', 'PM', 'STZ']
# 2022-05-01
# 2022-05-31
# ['AMD', 'CRM', 'CVX', 'J', 'KEY']
# 2022-06-01
# 2022-06-30
# ['AMD', 'DD', 'FCX', 'KEY', 'LMT']
# 2022-07-01
# 2022-07-31
# ['CB', 'CRM', 'DD', 'FCX', 'STZ']
# 2022-08-01
# 2022-08-31
# ['A', 'DD', 'JPM', 'REGN', 'STZ']
# 2022-09-01
# 2022-09-30
# ['ABT', 'DIS', 'L', 'META', 'MRNA']
# 2022-10-01
# 2022-10-31
# ['J', 'KEY', 'L', 'META', 'MU']
# 2022-11-01
# 2022-11-30
# ['A', 'DD', 'FCX', 'J', 'META']
# 2022-12-01
# 2022-12-31
# ['AEP', 'AES', 'DD', 'J', 'STZ']
# 2023-01-01
# 2023-01-31
# ['A', 'AES', 'DAL', 'J', 'KEY']
# 2023-02-01
# 2023-02-28
# ['A', 'AES', 'BIIB', 'FCX', 'MDT']

# %%
portfolio_df
# Out:
#             portfolio_return
# Date
# 2021-12-01         -0.016417
# 2021-12-02          0.024872
# 2021-12-03         -0.007711
# 2021-12-06          0.023926
# 2021-12-07          0.030547
# ...                      ...
# 2023-02-22         -0.007870
# 2023-02-23         -0.007323
# 2023-02-24         -0.009463
# 2023-02-27         -0.001871
# 2023-02-28          0.001403
#
# [312 rows x 1 columns]

# %%
#download NASDAQ/QQQ prices and calculate returns to compare to our strategy

# %%
qqq_df = yf.download(tickers='QQQ',
                     start='2021-01-01',
                     end='2023-03-01')
qqq_ret = np.log(qqq_df['Adj Close']).diff().to_frame('nasdaq_return')
portfolio_df = portfolio_df.merge(qqq_ret,
                                  left_index=True,
                                  right_index=True)
portfolio_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             portfolio_return  nasdaq_return
# Date
# 2021-12-01         -0.016417      -0.017159
# 2021-12-02          0.024872       0.007181
# 2021-12-03         -0.007711      -0.017542
# 2021-12-06          0.023926       0.007981
# 2021-12-07          0.030547       0.029669
# ...                      ...            ...
# 2023-02-22         -0.007870       0.000748
# 2023-02-23         -0.007323       0.008696
# 2023-02-24         -0.009463      -0.016886
# 2023-02-27         -0.001871       0.007136
# 2023-02-28          0.001403      -0.001294
#
# [312 rows x 2 columns]

# %%
portfolios_cumulative_return = np.exp(np.log1p(portfolio_df).cumsum()).sub(1)
portfolios_cumulative_return.plot(figsize=(16,6))
plt.title('Twitter Engagement Ratio Strategy Return Over Time')
plt.gca().yaxis.set_major_formatter(mtick.PercentageFormatter(1))
plt.ylabel('Return')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 portfolios_cumulative_return.plot(figsize=(16,6))
#       3 plt.title('Twitter Engagement Ratio Strategy Return Over Time')
# ----> 4 plt.gca().yaxis.set_major_formatter(mtick.PercentageFormatter(1))
#       5 plt.ylabel('Return')
#
# NameError: name 'mtick' is not defined

# %%
#if we use the likes/comments instead of engagementRatio to calculate the returns graph our prediction goes wrong  and returns will be less
