# %%
#This is the project for building stratergies using GARCH MODEL to predict the  movements, volatility of stocks and implement these stratergies to minimize the risk in intraday trading

# %%
#load simulated Data and simulated 5 min data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from arch import arch_model

# %%
daily_df = pd.read_csv('simulated_daily_data.csv')
daily_df
# Out:
#            Date         Open         High          Low        Close  \
# 0     9/17/2014   116.466003   117.043503   113.105499   114.333504
# 1     9/18/2014   114.214996   114.214996   103.276001   106.110001
# 2     9/19/2014   106.025749   106.958748    96.133003    98.698998
# 3     9/20/2014    98.668251   105.823998    97.470749   102.225998
# 4     9/21/2014   102.021248   103.106499    98.295250    99.705254
# ...         ...          ...          ...          ...          ...
# 3284  9/14/2023  6557.069336  6693.655762  6542.862793  6634.918457
# 3285  9/15/2023  6633.454590  6710.124512  6560.175293  6652.173340
# 3286  9/16/2023  6651.549805  6688.692383  6618.472656  6642.070313
# 3287  9/17/2023  6641.981934  6654.499512  6611.268555  6633.546875
# 3288  9/18/2023  6633.248535  6853.683594  6603.878906  6688.570313
#
#         Adj Close        Volume  Unnamed: 7
# 0      114.333504  2.105680e+07         NaN
# 1      106.110001  3.448320e+07         NaN
# 2       98.698998  3.791970e+07         NaN
# 3      102.225998  3.686360e+07         NaN
# 4       99.705254  2.658010e+07         NaN
# ...           ...           ...         ...
# 3284  6634.918457  1.381136e+10         NaN
# 3285  6652.173340  1.147974e+10         NaN
# 3286  6642.070313  7.402031e+09         NaN
# 3287  6633.546875  6.774211e+09         NaN
# 3288  6688.570313  1.561534e+10         NaN
#
# [3289 rows x 8 columns]

# %%
daily_df['Date'] = pd.to_datetime(daily_df['Date'])
daily_df = daily_df.set_index('Date')
daily_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-09-17   116.466003   117.043503   113.105499   114.333504   114.333504
# 2014-09-18   114.214996   114.214996   103.276001   106.110001   106.110001
# 2014-09-19   106.025749   106.958748    96.133003    98.698998    98.698998
# 2014-09-20    98.668251   105.823998    97.470749   102.225998   102.225998
# 2014-09-21   102.021248   103.106499    98.295250    99.705254    99.705254
# ...                 ...          ...          ...          ...          ...
# 2023-09-14  6557.069336  6693.655762  6542.862793  6634.918457  6634.918457
# 2023-09-15  6633.454590  6710.124512  6560.175293  6652.173340  6652.173340
# 2023-09-16  6651.549805  6688.692383  6618.472656  6642.070313  6642.070313
# 2023-09-17  6641.981934  6654.499512  6611.268555  6633.546875  6633.546875
# 2023-09-18  6633.248535  6853.683594  6603.878906  6688.570313  6688.570313
#
#                   Volume  Unnamed: 7
# Date
# 2014-09-17  2.105680e+07         NaN
# 2014-09-18  3.448320e+07         NaN
# 2014-09-19  3.791970e+07         NaN
# 2014-09-20  3.686360e+07         NaN
# 2014-09-21  2.658010e+07         NaN
# ...                  ...         ...
# 2023-09-14  1.381136e+10         NaN
# 2023-09-15  1.147974e+10         NaN
# 2023-09-16  7.402031e+09         NaN
# 2023-09-17  6.774211e+09         NaN
# 2023-09-18  1.561534e+10         NaN
#
# [3289 rows x 7 columns]

# %%
daily_df['log_ret'] = np.log(daily_df['Adj Close']).diff()
daily_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-09-17   116.466003   117.043503   113.105499   114.333504   114.333504
# 2014-09-18   114.214996   114.214996   103.276001   106.110001   106.110001
# 2014-09-19   106.025749   106.958748    96.133003    98.698998    98.698998
# 2014-09-20    98.668251   105.823998    97.470749   102.225998   102.225998
# 2014-09-21   102.021248   103.106499    98.295250    99.705254    99.705254
# ...                 ...          ...          ...          ...          ...
# 2023-09-14  6557.069336  6693.655762  6542.862793  6634.918457  6634.918457
# 2023-09-15  6633.454590  6710.124512  6560.175293  6652.173340  6652.173340
# 2023-09-16  6651.549805  6688.692383  6618.472656  6642.070313  6642.070313
# 2023-09-17  6641.981934  6654.499512  6611.268555  6633.546875  6633.546875
# 2023-09-18  6633.248535  6853.683594  6603.878906  6688.570313  6688.570313
#
#                   Volume  Unnamed: 7   log_ret
# Date
# 2014-09-17  2.105680e+07         NaN       NaN
# 2014-09-18  3.448320e+07         NaN -0.074643
# 2014-09-19  3.791970e+07         NaN -0.072402
# 2014-09-20  3.686360e+07         NaN  0.035111
# 2014-09-21  2.658010e+07         NaN -0.024968
# ...                  ...         ...       ...
# 2023-09-14  1.381136e+10         NaN  0.011801
# 2023-09-15  1.147974e+10         NaN  0.002597
# 2023-09-16  7.402031e+09         NaN -0.001520
# 2023-09-17  6.774211e+09         NaN -0.001284
# 2023-09-18  1.561534e+10         NaN  0.008261
#
# [3289 rows x 8 columns]

# %%
daily_df = daily_df.drop('Unnamed: 7', axis=1)
daily_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-09-17   116.466003   117.043503   113.105499   114.333504   114.333504
# 2014-09-18   114.214996   114.214996   103.276001   106.110001   106.110001
# 2014-09-19   106.025749   106.958748    96.133003    98.698998    98.698998
# 2014-09-20    98.668251   105.823998    97.470749   102.225998   102.225998
# 2014-09-21   102.021248   103.106499    98.295250    99.705254    99.705254
# ...                 ...          ...          ...          ...          ...
# 2023-09-14  6557.069336  6693.655762  6542.862793  6634.918457  6634.918457
# 2023-09-15  6633.454590  6710.124512  6560.175293  6652.173340  6652.173340
# 2023-09-16  6651.549805  6688.692383  6618.472656  6642.070313  6642.070313
# 2023-09-17  6641.981934  6654.499512  6611.268555  6633.546875  6633.546875
# 2023-09-18  6633.248535  6853.683594  6603.878906  6688.570313  6688.570313
#
#                   Volume   log_ret
# Date
# 2014-09-17  2.105680e+07       NaN
# 2014-09-18  3.448320e+07 -0.074643
# 2014-09-19  3.791970e+07 -0.072402
# 2014-09-20  3.686360e+07  0.035111
# 2014-09-21  2.658010e+07 -0.024968
# ...                  ...       ...
# 2023-09-14  1.381136e+10  0.011801
# 2023-09-15  1.147974e+10  0.002597
# 2023-09-16  7.402031e+09 -0.001520
# 2023-09-17  6.774211e+09 -0.001284
# 2023-09-18  1.561534e+10  0.008261
#
# [3289 rows x 7 columns]

# %%
intraday_5min_df = pd.read_csv('simulated_5min_data.csv')
intraday_5min_df
# Out:
#                datetime        open         low        high       close  \
# 0       9/29/2021 20:00  10379.7775  10364.5950  10398.7025  10370.9575
# 1       9/29/2021 20:05  10370.9425  10352.4175  10380.2500  10371.1450
# 2       9/29/2021 20:10  10372.8150  10357.8250  10388.7500  10384.3125
# 3       9/29/2021 20:15  10385.8275  10384.0825  10457.2000  10442.5175
# 4       9/29/2021 20:20  10442.5225  10426.2375  10448.0000  10440.9950
# ...                 ...         ...         ...         ...         ...
# 177872  9/20/2023 10:40   6792.1025   6783.6000   6796.2500   6790.1375
# 177873  9/20/2023 10:45   6790.5575   6779.1000   6795.7500   6781.9175
# 177874  9/20/2023 10:50   6781.5475   6779.3750   6790.2500   6783.9050
# 177875  9/20/2023 10:55   6783.9025   6779.9000   6793.2500   6782.0900
# 177876  9/20/2023 11:00   6783.7750   6774.3500   6787.5000   6778.6375
#
#         volume  Unnamed: 6
# 0           46         NaN
# 1           53         NaN
# 2          116         NaN
# 3          266         NaN
# 4           65         NaN
# ...        ...         ...
# 177872      41         NaN
# 177873      42         NaN
# 177874      44         NaN
# 177875      95         NaN
# 177876      54         NaN
#
# [177877 rows x 7 columns]

# %%
intraday_5min_df = intraday_5min_df.drop('Unnamed: 6', axis=1)
intraday_5min_df
# Out:
#                datetime        open         low        high       close  \
# 0       9/29/2021 20:00  10379.7775  10364.5950  10398.7025  10370.9575
# 1       9/29/2021 20:05  10370.9425  10352.4175  10380.2500  10371.1450
# 2       9/29/2021 20:10  10372.8150  10357.8250  10388.7500  10384.3125
# 3       9/29/2021 20:15  10385.8275  10384.0825  10457.2000  10442.5175
# 4       9/29/2021 20:20  10442.5225  10426.2375  10448.0000  10440.9950
# ...                 ...         ...         ...         ...         ...
# 177872  9/20/2023 10:40   6792.1025   6783.6000   6796.2500   6790.1375
# 177873  9/20/2023 10:45   6790.5575   6779.1000   6795.7500   6781.9175
# 177874  9/20/2023 10:50   6781.5475   6779.3750   6790.2500   6783.9050
# 177875  9/20/2023 10:55   6783.9025   6779.9000   6793.2500   6782.0900
# 177876  9/20/2023 11:00   6783.7750   6774.3500   6787.5000   6778.6375
#
#         volume
# 0           46
# 1           53
# 2          116
# 3          266
# 4           65
# ...        ...
# 177872      41
# 177873      42
# 177874      44
# 177875      95
# 177876      54
#
# [177877 rows x 6 columns]

# %%
intraday_5min_df['datetime'] = pd.to_datetime(intraday_5min_df['datetime'])
intraday_5min_df = intraday_5min_df.set_index('datetime')
intraday_5min_df
# Out:
#                            open         low        high       close  volume
# datetime
# 2021-09-29 20:00:00  10379.7775  10364.5950  10398.7025  10370.9575      46
# 2021-09-29 20:05:00  10370.9425  10352.4175  10380.2500  10371.1450      53
# 2021-09-29 20:10:00  10372.8150  10357.8250  10388.7500  10384.3125     116
# 2021-09-29 20:15:00  10385.8275  10384.0825  10457.2000  10442.5175     266
# 2021-09-29 20:20:00  10442.5225  10426.2375  10448.0000  10440.9950      65
# ...                         ...         ...         ...         ...     ...
# 2023-09-20 10:40:00   6792.1025   6783.6000   6796.2500   6790.1375      41
# 2023-09-20 10:45:00   6790.5575   6779.1000   6795.7500   6781.9175      42
# 2023-09-20 10:50:00   6781.5475   6779.3750   6790.2500   6783.9050      44
# 2023-09-20 10:55:00   6783.9025   6779.9000   6793.2500   6782.0900      95
# 2023-09-20 11:00:00   6783.7750   6774.3500   6787.5000   6778.6375      54
#
# [177877 rows x 5 columns]

# %%
intraday_5min_df.index.date
# Out:
# array([datetime.date(2021, 9, 29), datetime.date(2021, 9, 29),
#        datetime.date(2021, 9, 29), ..., datetime.date(2023, 9, 20),
#        datetime.date(2023, 9, 20), datetime.date(2023, 9, 20)],
#       dtype=object)

# %%
#define function to fit GARCH model and predict 1-day ahead volatility in a rolling window

# %%
daily_df['variance'] = daily_df['log_ret'].rolling(180).var()
daily_df['variance'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#forecast volatility of the predictions made

# %%
daily_df = daily_df['2020-01-01':]

def predict_volatility(x):
    best_model = arch_model(y=x, 
                            p=1, 
                            q=3).fit(update_freq=5, disp='off')
    variance_forecast = best_model.forecast(horizon=1).variance.iloc[-1,0]
    
    print(x.index[-1])

    return variance_forecast 
daily_df['predictions'] = daily_df['log_ret'].rolling(180).apply(lambda x: predict_volatility(x))
daily_df
# Out:
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002459. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002459. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-06-28 00:00:00
# 2020-06-29 00:00:00
# 2020-06-30 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002454. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002441. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002442. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-01 00:00:00
# 2020-07-02 00:00:00
# 2020-07-03 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002442. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00243. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-04 00:00:00
# 2020-07-05 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002417. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002422. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-06 00:00:00
# 2020-07-07 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00242. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002415. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-08 00:00:00
# 2020-07-09 00:00:00
# 2020-07-10 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002415. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002413. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002413. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-11 00:00:00
# 2020-07-12 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002377. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002377. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-13 00:00:00
# 2020-07-14 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002377. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002374. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-15 00:00:00
# 2020-07-16 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002374. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00237. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-17 00:00:00
# 2020-07-18 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00237. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002369. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-19 00:00:00
# 2020-07-20 00:00:00
# 2020-07-21 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002369. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002366. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002367. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-22 00:00:00
# 2020-07-23 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002367. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002363. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-24 00:00:00
# 2020-07-25 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002357. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:765: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002347. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-26 00:00:00
# 2020-07-27 00:00:00
# 2020-07-28 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002406. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002404. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002404. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-07-29 00:00:00
# 2020-07-30 00:00:00
# 2020-07-31 00:00:00
# 2020-08-01 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002404. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002406. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002413. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002434. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-08-02 00:00:00
# 2020-08-03 00:00:00
# 2020-08-04 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002424. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002424. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002435. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-08-05 00:00:00
# 2020-08-06 00:00:00
# 2020-08-07 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002435. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002433. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00243. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:765: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002424. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002425. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002433. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002434. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002425. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002425. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002422. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-08-08 00:00:00
# 2020-08-09 00:00:00
# 2020-08-10 00:00:00
# 2020-08-11 00:00:00
# 2020-08-12 00:00:00
# 2020-08-13 00:00:00
# 2020-08-14 00:00:00
# 2020-08-15 00:00:00
# 2020-08-16 00:00:00
# 2020-08-17 00:00:00
# 2020-08-18 00:00:00
# 2020-08-19 00:00:00
# 2020-08-20 00:00:00
# 2020-08-21 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002411. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0024. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002403. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002405. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002406. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002405. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002401. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002395. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002376. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002383. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002383. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002383. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002385. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002379. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00238. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002379. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002376. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-03 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002389. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002452. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002404. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-09-04 00:00:00
# 2020-09-05 00:00:00
# 2020-09-06 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002408. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002408. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002408. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-09-07 00:00:00
# 2020-09-08 00:00:00
# 2020-09-09 00:00:00
# 2020-09-10 00:00:00
# 2020-09-11 00:00:00
# 2020-09-12 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001198. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001132. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001105. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001099. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001066. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00106. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-09-13 00:00:00
# 2020-09-14 00:00:00
# 2020-09-15 00:00:00
# 2020-09-16 00:00:00
# 2020-09-17 00:00:00
# 2020-09-18 00:00:00
# 2020-09-19 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001065. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009166. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009175. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009175. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000896. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000849. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008391. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-09-20 00:00:00
# 2020-09-21 00:00:00
# 2020-09-22 00:00:00
# 2020-09-23 00:00:00
# 2020-09-24 00:00:00
# 2020-09-25 00:00:00
# 2020-09-26 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008508. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008509. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008472. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008508. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000834. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0007992. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0007991. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2020-09-27 00:00:00
# 2020-09-28 00:00:00
# 2020-09-29 00:00:00
# 2020-09-30 00:00:00
# 2020-10-01 00:00:00
# 2020-10-02 00:00:00
# 2020-10-03 00:00:00
# 2020-10-04 00:00:00
# ...
# estimating the model parameters. The scale of y is 0.0005158. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005164. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2023-08-24 00:00:00
# 2023-08-25 00:00:00
# 2023-08-26 00:00:00
# 2023-08-27 00:00:00
# 2023-08-28 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005152. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005151. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005136. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005112. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005306. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2023-08-29 00:00:00
# 2023-08-30 00:00:00
# 2023-08-31 00:00:00
# 2023-09-01 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005185. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005336. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005338. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005338. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2023-09-02 00:00:00
# 2023-09-03 00:00:00
# 2023-09-04 00:00:00
# 2023-09-05 00:00:00
# 2023-09-06 00:00:00
# 2023-09-07 00:00:00
# 2023-09-08 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005333. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005304. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005066. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000506. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005054. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004788. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004366. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2023-09-09 00:00:00
# 2023-09-10 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000434. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004366. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2023-09-11 00:00:00
# 2023-09-12 00:00:00
# 2023-09-13 00:00:00
# 2023-09-14 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004362. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003921. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003913. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003828. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# 2023-09-15 00:00:00
# 2023-09-16 00:00:00
# 2023-09-17 00:00:00
# 2023-09-18 00:00:00
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003823. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003811. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:310: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003761. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\Raghav N\AppData\Local\Temp\ipykernel_25124\3004602784.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df['predictions'] = daily_df['log_ret'].rolling(180).apply(lambda x: predict_volatility(x))
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01  1798.723022  1813.582642  1793.736084  1800.043579  1800.043579
# 2020-01-02  1800.637817  1803.038818  1733.817505  1746.367554  1746.367554
# 2020-01-03  1746.107178  1853.428833  1728.749023  1836.221069  1836.221069
# 2020-01-04  1836.343872  1856.846436  1827.378540  1852.664185  1852.664185
# 2020-01-05  1852.612915  1886.124268  1850.133911  1852.829346  1852.829346
# ...                 ...          ...          ...          ...          ...
# 2023-09-14  6557.069336  6693.655762  6542.862793  6634.918457  6634.918457
# 2023-09-15  6633.454590  6710.124512  6560.175293  6652.173340  6652.173340
# 2023-09-16  6651.549805  6688.692383  6618.472656  6642.070313  6642.070313
# 2023-09-17  6641.981934  6654.499512  6611.268555  6633.546875  6633.546875
# 2023-09-18  6633.248535  6853.683594  6603.878906  6688.570313  6688.570313
#
#                   Volume   log_ret  variance  predictions
# Date
# 2020-01-01  1.856566e+10  0.000914  0.001125          NaN
# 2020-01-02  2.080208e+10 -0.030273  0.001127          NaN
# 2020-01-03  2.811148e+10  0.050172  0.001139          NaN
# 2020-01-04  1.844427e+10  0.008915  0.001110          NaN
# 2020-01-05  1.972507e+10  0.000089  0.001106          NaN
# ...                  ...       ...       ...          ...
# 2023-09-14  1.381136e+10  0.011801  0.000393     0.000334
# 2023-09-15  1.147974e+10  0.002597  0.000385     0.000292
# 2023-09-16  7.402031e+09 -0.001520  0.000384     0.000286
# 2023-09-17  6.774211e+09 -0.001284  0.000383     0.000280
# 2023-09-18  1.561534e+10  0.008261  0.000378     0.000298
#
# [1357 rows x 9 columns]

# %%
daily_df[['variance', 'predictions']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#calculate prediction premium and form a daily signal from it

# %%
daily_df['prediction_premium'] = (daily_df['predictions'] - daily_df['variance'])/daily_df['variance']
daily_df['premium_std'] = daily_df['prediction_premium'].rolling(180).std()
# Out:
# C:\Users\Raghav N\AppData\Local\Temp\ipykernel_25124\1332053247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df['prediction_premium'] = (daily_df['predictions'] - daily_df['variance'])/daily_df['variance']
# C:\Users\Raghav N\AppData\Local\Temp\ipykernel_25124\1332053247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df['premium_std'] = daily_df['prediction_premium'].rolling(180).std()

# %%
daily_df['prediction_premium'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
daily_df['premium_std'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#prediction premium is potential profit that can be made by forecasting or predicting changes in volatility. 
#prediction std is volatility associated with a financial market prediction or forecast.

# %%
daily_df['signal_daily'] = daily_df.apply(lambda x: 1 if(x['prediction_premium']>x['premium_std']*1.5)
                                                      else(-1 if(x['prediction_premium']<x['premium_std']*-1.5)else np.nan),
                                          axis=1)
daily_df
# Out:
# C:\Users\Raghav N\AppData\Local\Temp\ipykernel_25124\2771703816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df['signal_daily'] = daily_df.apply(lambda x: 1 if(x['prediction_premium']>x['premium_std']*1.5)
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01  1798.723022  1813.582642  1793.736084  1800.043579  1800.043579
# 2020-01-02  1800.637817  1803.038818  1733.817505  1746.367554  1746.367554
# 2020-01-03  1746.107178  1853.428833  1728.749023  1836.221069  1836.221069
# 2020-01-04  1836.343872  1856.846436  1827.378540  1852.664185  1852.664185
# 2020-01-05  1852.612915  1886.124268  1850.133911  1852.829346  1852.829346
# ...                 ...          ...          ...          ...          ...
# 2023-09-14  6557.069336  6693.655762  6542.862793  6634.918457  6634.918457
# 2023-09-15  6633.454590  6710.124512  6560.175293  6652.173340  6652.173340
# 2023-09-16  6651.549805  6688.692383  6618.472656  6642.070313  6642.070313
# 2023-09-17  6641.981934  6654.499512  6611.268555  6633.546875  6633.546875
# 2023-09-18  6633.248535  6853.683594  6603.878906  6688.570313  6688.570313
#
#                   Volume   log_ret  variance  predictions  prediction_premium  \
# Date
# 2020-01-01  1.856566e+10  0.000914  0.001125          NaN                 NaN
# 2020-01-02  2.080208e+10 -0.030273  0.001127          NaN                 NaN
# 2020-01-03  2.811148e+10  0.050172  0.001139          NaN                 NaN
# 2020-01-04  1.844427e+10  0.008915  0.001110          NaN                 NaN
# 2020-01-05  1.972507e+10  0.000089  0.001106          NaN                 NaN
# ...                  ...       ...       ...          ...                 ...
# 2023-09-14  1.381136e+10  0.011801  0.000393     0.000334           -0.151792
# 2023-09-15  1.147974e+10  0.002597  0.000385     0.000292           -0.240810
# 2023-09-16  7.402031e+09 -0.001520  0.000384     0.000286           -0.256793
# 2023-09-17  6.774211e+09 -0.001284  0.000383     0.000280           -0.268903
# 2023-09-18  1.561534e+10  0.008261  0.000378     0.000298           -0.211600
#
#             premium_std  signal_daily
# Date
# 2020-01-01          NaN           NaN
# 2020-01-02          NaN           NaN
# 2020-01-03          NaN           NaN
# 2020-01-04          NaN           NaN
# 2020-01-05          NaN           NaN
# ...                 ...           ...
# 2023-09-14     0.549073           NaN
# 2023-09-15     0.546370           NaN
# 2023-09-16     0.545350           NaN
# 2023-09-17     0.545207           NaN
# 2023-09-18     0.544362           NaN
#
# [1357 rows x 12 columns]

# %%
 # plot a histogram for this signal_daily

# %%
daily_df['signal_daily'].plot(kind='hist')
plt.show()

# %%
daily_df['signal_daily'] = daily_df['signal_daily'].shift()
daily_df
# Out:
# C:\Users\Raghav N\AppData\Local\Temp\ipykernel_25124\2560492430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df['signal_daily'] = daily_df['signal_daily'].shift()
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01  1798.723022  1813.582642  1793.736084  1800.043579  1800.043579
# 2020-01-02  1800.637817  1803.038818  1733.817505  1746.367554  1746.367554
# 2020-01-03  1746.107178  1853.428833  1728.749023  1836.221069  1836.221069
# 2020-01-04  1836.343872  1856.846436  1827.378540  1852.664185  1852.664185
# 2020-01-05  1852.612915  1886.124268  1850.133911  1852.829346  1852.829346
# ...                 ...          ...          ...          ...          ...
# 2023-09-14  6557.069336  6693.655762  6542.862793  6634.918457  6634.918457
# 2023-09-15  6633.454590  6710.124512  6560.175293  6652.173340  6652.173340
# 2023-09-16  6651.549805  6688.692383  6618.472656  6642.070313  6642.070313
# 2023-09-17  6641.981934  6654.499512  6611.268555  6633.546875  6633.546875
# 2023-09-18  6633.248535  6853.683594  6603.878906  6688.570313  6688.570313
#
#                   Volume   log_ret  variance  predictions  prediction_premium  \
# Date
# 2020-01-01  1.856566e+10  0.000914  0.001125          NaN                 NaN
# 2020-01-02  2.080208e+10 -0.030273  0.001127          NaN                 NaN
# 2020-01-03  2.811148e+10  0.050172  0.001139          NaN                 NaN
# 2020-01-04  1.844427e+10  0.008915  0.001110          NaN                 NaN
# 2020-01-05  1.972507e+10  0.000089  0.001106          NaN                 NaN
# ...                  ...       ...       ...          ...                 ...
# 2023-09-14  1.381136e+10  0.011801  0.000393     0.000334           -0.151792
# 2023-09-15  1.147974e+10  0.002597  0.000385     0.000292           -0.240810
# 2023-09-16  7.402031e+09 -0.001520  0.000384     0.000286           -0.256793
# 2023-09-17  6.774211e+09 -0.001284  0.000383     0.000280           -0.268903
# 2023-09-18  1.561534e+10  0.008261  0.000378     0.000298           -0.211600
#
#             premium_std  signal_daily
# Date
# 2020-01-01          NaN           NaN
# 2020-01-02          NaN           NaN
# 2020-01-03          NaN           NaN
# 2020-01-04          NaN           NaN
# 2020-01-05          NaN           NaN
# ...                 ...           ...
# 2023-09-14     0.549073           NaN
# 2023-09-15     0.546370           NaN
# 2023-09-16     0.545350           NaN
# 2023-09-17     0.545207           NaN
# 2023-09-18     0.544362           NaN
#
# [1357 rows x 12 columns]

# %%
 final_df = intraday_5min_df.reset_index()\
.merge(daily_df[['signal_daily']].reset_index(),
      left_on='datetime',
      right_on='Date')\
.set_index('datetime')
final_df
# Out:
#                   open         low         high       close  volume  \
# datetime
# 2021-09-30  10907.7500  10900.0000  10964.99626  10941.7325     240
# 2021-10-01  10910.5900  10890.6750  10929.57250  10905.8500      30
# 2021-10-02  11887.2500  11875.0000  11899.38750  11892.9850      24
# 2021-10-04  11872.6075  11849.0000  11879.30500  11855.0000      70
# 2021-10-05  12330.0375  12297.0475  12337.25000  12300.0675      33
# ...                ...         ...          ...         ...     ...
# 2023-09-13   6468.4500   6463.6000   6478.50000   6471.8475      21
# 2023-09-14   6568.3750   6566.9025   6570.00000   6568.6400       6
# 2023-09-15   6657.5250   6654.8925   6661.25000   6656.8625      10
# 2023-09-16   6659.6250   6648.6475   6660.25000   6649.3975      35
# 2023-09-18   6666.3525   6665.9000   6675.50000   6667.7000      24
#
#                  Date  signal_daily
# datetime
# 2021-09-30 2021-09-30           NaN
# 2021-10-01 2021-10-01           NaN
# 2021-10-02 2021-10-02           NaN
# 2021-10-04 2021-10-04           NaN
# 2021-10-05 2021-10-05           NaN
# ...               ...           ...
# 2023-09-13 2023-09-13           NaN
# 2023-09-14 2023-09-14           NaN
# 2023-09-15 2023-09-15           NaN
# 2023-09-16 2023-09-16           NaN
# 2023-09-18 2023-09-18           NaN
#
# [616 rows x 7 columns]

# %%
# \ is used to just code the continuation in next line

# %%
final_df = final_df.drop('Date', axis=1)
final_df
# Out:
#                   open         low         high       close  volume  \
# datetime
# 2021-09-30  10907.7500  10900.0000  10964.99626  10941.7325     240
# 2021-10-01  10910.5900  10890.6750  10929.57250  10905.8500      30
# 2021-10-02  11887.2500  11875.0000  11899.38750  11892.9850      24
# 2021-10-04  11872.6075  11849.0000  11879.30500  11855.0000      70
# 2021-10-05  12330.0375  12297.0475  12337.25000  12300.0675      33
# ...                ...         ...          ...         ...     ...
# 2023-09-13   6468.4500   6463.6000   6478.50000   6471.8475      21
# 2023-09-14   6568.3750   6566.9025   6570.00000   6568.6400       6
# 2023-09-15   6657.5250   6654.8925   6661.25000   6656.8625      10
# 2023-09-16   6659.6250   6648.6475   6660.25000   6649.3975      35
# 2023-09-18   6666.3525   6665.9000   6675.50000   6667.7000      24
#
#             signal_daily
# datetime
# 2021-09-30           NaN
# 2021-10-01           NaN
# 2021-10-02           NaN
# 2021-10-04           NaN
# 2021-10-05           NaN
# ...                  ...
# 2023-09-13           NaN
# 2023-09-14           NaN
# 2023-09-15           NaN
# 2023-09-16           NaN
# 2023-09-18           NaN
#
# [616 rows x 6 columns]

# %%
#use indicators

# %%
import pandas_ta
final_df['rsi'] = pandas_ta.rsi(close=final_df['close'],
                                length=20)
final_df['lband'] = pandas_ta.bbands(close=final_df['close'],
                                length=20).iloc[:,0]
final_df['mband'] = pandas_ta.bbands(close=final_df['close'],
                                length=20).iloc[:,1]
final_df['uband'] = pandas_ta.bbands(close=final_df['close'],
                                length=20).iloc[:,2]
final_df
# Out:
#                   open         low         high       close  volume  \
# datetime
# 2021-09-30  10907.7500  10900.0000  10964.99626  10941.7325     240
# 2021-10-01  10910.5900  10890.6750  10929.57250  10905.8500      30
# 2021-10-02  11887.2500  11875.0000  11899.38750  11892.9850      24
# 2021-10-04  11872.6075  11849.0000  11879.30500  11855.0000      70
# 2021-10-05  12330.0375  12297.0475  12337.25000  12300.0675      33
# ...                ...         ...          ...         ...     ...
# 2023-09-13   6468.4500   6463.6000   6478.50000   6471.8475      21
# 2023-09-14   6568.3750   6566.9025   6570.00000   6568.6400       6
# 2023-09-15   6657.5250   6654.8925   6661.25000   6656.8625      10
# 2023-09-16   6659.6250   6648.6475   6660.25000   6649.3975      35
# 2023-09-18   6666.3525   6665.9000   6675.50000   6667.7000      24
#
#             signal_daily        rsi        lband        mband        uband
# datetime
# 2021-09-30           NaN        NaN          NaN          NaN          NaN
# 2021-10-01           NaN        NaN          NaN          NaN          NaN
# 2021-10-02           NaN        NaN          NaN          NaN          NaN
# 2021-10-04           NaN        NaN          NaN          NaN          NaN
# 2021-10-05           NaN        NaN          NaN          NaN          NaN
# ...                  ...        ...          ...          ...          ...
# 2023-09-13           NaN  39.993368  6305.282103  6525.313250  6745.344397
# 2023-09-14           NaN  43.690384  6307.696213  6528.355875  6749.015537
# 2023-09-15           NaN  46.833115  6309.574455  6536.495750  6763.417045
# 2023-09-16           NaN  46.601455  6308.307792  6538.768125  6769.228458
# 2023-09-18           NaN  47.274549  6309.173952  6546.136875  6783.099798
#
# [616 rows x 10 columns]

# %%
final_df['signal_intraday'] = final_df.apply(lambda x: 1 if (x['rsi']>70)&
                                                            (x['close']>x['uband'])
                                             else (-1 if (x['rsi']<30)&
                                                         (x['close']<x['lband']) else np.nan),
                                             axis=1)

# %%
final_df['return'] = np.log(final_df['close']).diff()

final_df
# Out:
#                   open         low         high       close  volume  \
# datetime
# 2021-09-30  10907.7500  10900.0000  10964.99626  10941.7325     240
# 2021-10-01  10910.5900  10890.6750  10929.57250  10905.8500      30
# 2021-10-02  11887.2500  11875.0000  11899.38750  11892.9850      24
# 2021-10-04  11872.6075  11849.0000  11879.30500  11855.0000      70
# 2021-10-05  12330.0375  12297.0475  12337.25000  12300.0675      33
# ...                ...         ...          ...         ...     ...
# 2023-09-13   6468.4500   6463.6000   6478.50000   6471.8475      21
# 2023-09-14   6568.3750   6566.9025   6570.00000   6568.6400       6
# 2023-09-15   6657.5250   6654.8925   6661.25000   6656.8625      10
# 2023-09-16   6659.6250   6648.6475   6660.25000   6649.3975      35
# 2023-09-18   6666.3525   6665.9000   6675.50000   6667.7000      24
#
#             signal_daily        rsi        lband        mband        uband  \
# datetime
# 2021-09-30           NaN        NaN          NaN          NaN          NaN
# 2021-10-01           NaN        NaN          NaN          NaN          NaN
# 2021-10-02           NaN        NaN          NaN          NaN          NaN
# 2021-10-04           NaN        NaN          NaN          NaN          NaN
# 2021-10-05           NaN        NaN          NaN          NaN          NaN
# ...                  ...        ...          ...          ...          ...
# 2023-09-13           NaN  39.993368  6305.282103  6525.313250  6745.344397
# 2023-09-14           NaN  43.690384  6307.696213  6528.355875  6749.015537
# 2023-09-15           NaN  46.833115  6309.574455  6536.495750  6763.417045
# 2023-09-16           NaN  46.601455  6308.307792  6538.768125  6769.228458
# 2023-09-18           NaN  47.274549  6309.173952  6546.136875  6783.099798
#
#             signal_intraday    return
# datetime
# 2021-09-30              NaN       NaN
# 2021-10-01              NaN -0.003285
# 2021-10-02              NaN  0.086649
# 2021-10-04              NaN -0.003199
# 2021-10-05              NaN  0.036855
# ...                     ...       ...
# 2023-09-13              NaN  0.000927
# 2023-09-14              NaN  0.014845
# 2023-09-15              NaN  0.013341
# 2023-09-16              NaN -0.001122
# 2023-09-18              NaN  0.002749
#
# [616 rows x 12 columns]

# %%
#generate the position entry and hold till the end of the day

# %%
final_df['return_sign'] = final_df.apply(lambda x: -1 if (x['signal_daily']==1)&(x['signal_intraday']==1)
                                        else (1 if (x['signal_daily']==-1)&(x['signal_intraday']==-1) else np.nan),
                                        axis=1)

final_df['return_sign'] = final_df.groupby(pd.Grouper(freq='D'))['return_sign']\
                                  .transform(lambda x: x.ffill())

final_df['forward_return'] = final_df['return'].shift(-1)

final_df['strategy_return'] = final_df['forward_return']*final_df['return_sign']

daily_return_df = final_df.groupby(pd.Grouper(freq='D'))['strategy_return'].sum()

# %%
#calculate final stratergy returns

# %%
import matplotlib.ticker as mtick

strategy_cumulative_return = np.exp(np.log1p(daily_return_df).cumsum()).sub(1)

strategy_cumulative_return.plot(figsize=(16,6))

plt.title('Intraday Strategy Returns')

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.ylabel('Return')

plt.show()
